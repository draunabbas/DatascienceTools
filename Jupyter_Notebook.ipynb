# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Peer-graded Assignment
# Exercise 2 - Create a markdown cell with the title of the notebook.

# %% [markdown]
# #### Introduction  (Exercise 3)
# * This notebook demonstrates the features of Jupyter notebook

# %% [markdown]
# #### List of Data Science languages (Exercise 4)
# 1. R
# 2. Python
# 3. Scala
# 4. Julia
#
#
#
#
# Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)

# %% [markdown]
# #### List of data science libraries (Exercise 5)
#
# - NumPy: A library for scientific computing and performing basic and advanced array operations
# - SciPy: A library that includes modules for linear algebra, integration, optimization, and statistics
# - Pandas: A library created to help developers work with “labeled” and “relational” data intuitively
# - Scikit-learn: A library for machine learning tasks such as classification, regression, and clustering 3. TensorFlow: An open-source machine learning library developed at Google for numerical computation using data flow graphs
# - Keras: A high-level neural networks API, written in Python and capable of running on top of TensorFlow, CNTK, or Theano
# - Matplotlib: A plotting library for the Python programming language and its numerical mathematics extension NumPy
#  - Seaborn: A library for making statistical graphics in Python
# - Bokeh: A Python library for creating interactive visualizations for modern web browsers - Plotly: A Python graphing library that makes interactive, publication-quality graphs online.

# %% [markdown]
# #### table of Data Science tools(Exercise 6)
# |Tool Name        |Description                                          |
# |-----------------|-----------------------------------------------------|
# |MS Excel         |A fundamental tool for data analysis and visualization. It comes with built-in formulae and provides various types of data visualization elements like charts and graphs    |
# |BigML             |An online, cloud-based, event-driven tool that helps in data science and machine learning operations. This GUI-based tool allows beginners who have little or no previous experience in creating models through drag and drop features      |
# |Google Analytics   |A web analytics service that tracks and reports website traffic|
# |Apache Spark       |An open-source distributed computing system that is used for big data processing and analytics     |
# |Matlab             |A programming language and numerical computing environment that is used for data analysis, algorithm development, and modeling   |
# |SAS                |A software suite that is used for advanced analytics, multivariate analyses, business intelligence, data management, and predictive analytics   |
# |KNIME              |An open-source data analytics, reporting, and integration platform that is used for data mining, machine learning, and predictive analytics    |
# |Apache Flink       |An open-source stream processing framework that is used for real-time data processing and analytics    |

# %%
# arithmetic expression examples. (Exercise 7)


3+4*2-(2/3)
# Out:
# 10.333333333333334

# %%
# multiply and add numbers ( Exercise 8) 

3*4+7
# Out:
# 19

# %%
####  Convert minutes to hours ( Exercise 9) 

minutes = 6
hours = 6* 60
print(hours)
# Out:
# 360

# %% [markdown]
# ####  list of Objectives. ( Exercise 10)
#
# - Describe how to use the notebooks in JupyterLab.
# - Describe how to work in a notebook session.
# - Describe the basic Jupyter architecture.
# - Describe how to work with kernels.
# - Identify tools in Anaconda Jupyter environments.

# %% [markdown]
# ####  Author’s name ( Exercise 11)
#
# #Muhammad Aun Abbas

# %% [markdown]
# ####  Share notebook through GitHub( Exercise 12)
# created , please see left pan

# %% [markdown]
# ####  Screenshot of first page of notebook ( Exercise 13)
# ![image.png](attachment:1d3b731a-a69f-48c4-aad6-9ff2b7533627.png)
